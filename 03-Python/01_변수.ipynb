# %% [markdown]
# # 01_변수.ipynb
#
# ## 시작에 앞서
#
# 1. 주석(comment) → 사람은 읽지만, 코드는 아닌 메모(#으로 시작)
# 2. 들여쓰기(indent) → 4칸을 안쪽으로 들여 씀

# %% [markdown]
# * 변수는 박스
# * 변수 a에 10이라는 값을 저장(할당)한다.
# * = 할당자는 프로그래밍에서는 "우측의 값을 좌측의 변수에 저장한다."

# %%
a=10
a=20
a
# Out:
# 20

# %%
i=5
j=3
s='파이썬'

print(i,j,s)
# Out:
# 5 3 파이썬

# %%
i+j
i-j
# Out:
# 2

# %%
a = 1
b = 2

a = a+b

print(a)
# Out:
# 3

# %%
s + ' 쉽다'
# Out:
# '파이썬 쉽다'

# %%
a = 1
b = 2
c = 3

x, y, z = 10, 20, 30

print(z)
# Out:
# 30

# %%
# 문제
# x = 10, y = 20일 때, 값을 서로 교체하는 코드를 작성해 보자.

x, y = 10, 20
y = y-x
x = 2*x


print(x, y) # 20, 10
# Out:
# 20 10

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## 변수명(식별자)
# 1. 대소문자 다 됨. Apple 과 apple 다른거
# 1. 한글 됨(안씀)
# 1. 미리 예약된 특수 단어들은 안 됨
# 1. 미리 점유된 이름들은 됨(쓰면 안 됨)
#
# ## Convention 국룰
# 1. 일반 변수명은 모두 소문자,_로 구분
# 1. 일반 함수명도 "
# 1. 상수는 모두 대문자
# 1. 클래스는 첫글자만 대문자
#
# ## 자료형(Data Type)
#
# ### Boolean (참/거짓)
# - int(정수)
# - float(실수)
# - *complex(복소수)*
# ### Numeric (숫자)
# ### String (문자)
# ### None (없음)

# %%
# Boolean

type(True), type(False)
# Out:
# (bool, bool)

# %%
# bool() 함수 → 특정 데이터가 True, False인지 검증 → 비어있다, 없다 같은 애들만 False
bool(0), bool(-100), bool(10)
# Out:
# (False, True, True)

# %%
bool('hello'), bool('')
# Out:
# (True, False)

# %%
bool([1,2,3]), bool([])
# Out:
# (True, False)

# %%
# int
i = 3
type(i)
# Out:
# int

# %%
#파이썬은 메모리 오버플로우 걱정 없음! → 아주 큰 수도 문제 없다.
i = 2**100
print(i)
# Out:
# 1267650600228229401496703205376

# %%
# float (실수)
f = 3.5
type(f)
# Out:
# float

# %%
a = 3.5 - 3.12

import math
math.isclose(0.38, a)
# Out:
# True

# %% [markdown]
# ### String (문자)
#
# ## 문자열 표현법
# 문자열 표현법(쌍&홑 따옴표 모두 가능)
# - `'a'`
# - `"a"`
# - `'''a'''`
# - `"""a"""`

# %%
s = 'hello'
h = 'python'
print(s +h)
# Out:
# hellopython

# %%
ss = '안녕하세요\n반갑습니다'
print(ss)
# Out:
# 안녕하세요
# 반갑습니다

# %%
name = '마이클'
age = 24

#greeting = name + '님 환영합니다! ' + name + '님의 등급은 ~~입니다.'
#print(greeting)

greeting = f'{name}님 환영합니다! {name}님의 나이는 {age}살 입니다.'
print(greeting)
# Out:
# 마이클님 환영합니다! 마이클님의 나이는 24살 입니다.

# %%
# String 안에서 따옴표 사용하기
title = 'lily\'s bag'
story = '그는 말했다 \"안녕?..\" 이라고..'

# %%
story
# Out:
# '그는 말했다 "안녕?.." 이라고..'

# %% [markdown]
# ## None(없음)

# %%
# True / False / None
type(None)
# Out:
# NoneType
