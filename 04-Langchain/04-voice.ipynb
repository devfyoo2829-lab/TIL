# %% [markdown]
# # 04-voice.ipynb
#
# `사용자 오디오 입력` → `STT(말→글)` → `Agent` → `TTS(글→말)` → `기계 오디오 출력`

# %% [markdown]
# `pip install assemblyai cartesia`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True
