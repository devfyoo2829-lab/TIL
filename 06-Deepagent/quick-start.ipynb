# %% [markdown]
# # quick-start.ipynb

# %% [markdown]
# - `.env`에 `TAVILY_API_KEY` 추가 필요

# %% [markdown]
# ## Deep Agent
# 기존 Langchain Agent보다
# 1. 계획 세우기
# 1. 파일 시스템 Tools
# 1. 하위 에이전트 다루는 능력

# %% [markdown]
# uv `pip install deepagents tavily-python ipykernel`
#
# uv `pip install python-dotenv`
#
# uv `pip install langchain-openai`

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from typing import Literal
from tavily import TavilyClient
from langchain.tools import tool

TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')
tavily_client = TavilyClient(api_key=TAVILY_API_KEY)

def internet_search(
        query: str,
        max_results: int = 5, # = 뒤에는 기본값
        topic: Literal['general', 'news', 'finance'] = 'general',
        include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic
    )

# %%
from deepagents import create_deep_agent

SYSTEM_PROMPT="""You are an expert researcher. Your job is to conduct thorough research and then write a polished report.

You have access to an internet search tool as your primary means of gathering information.

## `internet_search`

Use this to run an internet search for a given query. You can specify the max number of results to return, the topic, and whether raw content should be included.
"""

deep_agent = create_deep_agent(
    model='openai:gpt-5-mini',
    tools=[internet_search],
    system_prompt=SYSTEM_PROMPT
)

# %%
deep_agent.invoke({
    'messages':[
        {'role': 'user', 'content': '랭체인 1.0 버전 전과 후를 비교해줘.'
        'langchain, langgraph, langsmith에 대해서 설명 및 달라진 점 말해주고,'
        '랭체인에서 deepagent가 새로 나왔는데 이것도 말해줘.'}]
})
# Out:
# {'messages': [HumanMessage(content='랭체인 1.0 버전 전과 후를 비교해줘.langchain, langgraph, langsmith에 대해서 설명 및 달라진 점 말해주고,랭체인에서 deepagent가 새로 나왔는데 이것도 말해줘.', additional_kwargs={}, response_metadata={}, id='5ba763b6-da67-4a31-9310-867a6a72f903'),
#   AIMessage(content=[{'id': 'rs_0d9a4129d16179220069af7bb9f8348190b338878d8acfe797', 'summary': [], 'type': 'reasoning'}, {'arguments': '{"query":"LangChain 1.0 release notes LangGraph LangSmith DeepAgent","max_results":5,"topic":"general","include_raw_content":false}', 'call_id': 'call_6jMRnNCzxeupZbfVVhb1VrG1', 'name': 'internet_search', 'type': 'function_call', 'id': 'fc_0d9a4129d16179220069af7bbfa5308190b96eec2f8b4db307', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0d9a4129d16179220069af7bb98e548190a163b1dde01eebae', 'created_at': 1773108153.0, 'metadata': {}, 'model': 'gpt-5-mini-2025-08-07', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07'}, id='resp_0d9a4129d16179220069af7bb98e548190a163b1dde01eebae', tool_calls=[{'name': 'internet_search', 'args': {'query': 'LangChain 1.0 release notes LangGraph LangSmith DeepAgent', 'max_results': 5, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_6jMRnNCzxeupZbfVVhb1VrG1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 5161, 'output_tokens': 295, 'total_tokens': 5456, 'input_token_details': {'cache_read': 4608}, 'output_token_details': {'reasoning': 192}}),
#   ToolMessage(content='{"query": "LangChain 1.0 release notes LangGraph LangSmith DeepAgent", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://changelog.langchain.com/?date=2026-01-01&page=2", "title": "LangChain - Changelog", "content": "## `deepagents` 0.2 release for more autonomous agents. ## Discover patterns in production traces with the Insights Agent. Insights Agent helps you find signal into your traces by analyzing... This release includes improvements to evaluations: online multi-turn evaluations, composite feedback scores and JavaScript code evals. ## Evaluate end-to-end agent interactions with Multi-turn Evals. Today, we\'re launching Multi-turn Evals to help you measure how your agent is performing across an entire end-to-end interaction. Multi-turn evals are online... LangGraph 1.0 is the first stable major release in the durable agent framework space —a major milestone for production-ready AI systems. ## LangChain 1.0 now generally available. LangChain 1.0 is our first major stable release, marking our commitment to no breaking changes until 2.0. ## Product naming changes: LangSmith Deployment and LangSmith Studio. We’ve updated product names across the LangSmith UI, docs, and website to make it clearer how our tools fit together. ## JavaScript Code Evals for faster eval workflows. ## Composite Evaluators in LangSmith.", "score": 0.83678174, "raw_content": null}, {"url": "https://changelog.langchain.com/announcements/langchain-1-0-now-generally-available", "title": "LangChain 1.0 now generally available", "content": "LangChain - Changelog | LangChain 1.0 now generally available. [LangChain](https://www.langchain.com/langchain)[LangSmith](https://www.langchain.com/langsmith)[LangGraph](https://www.langchain.com/langgraph). [Retrieval](https://www.langchain.com/retrieval)[Agents](https://www.langchain.com/agents)[Evaluation](https://www.langchain.com/evaluation). [Blog](https://blog.langchain.dev/)[Case Studies](https://www.langchain.com/case-studies)[LangChain Academy](https://academy.langchain.com/)[Community](https://www.langchain.com/community)[Experts](https://www.langchain.com/experts)[Changelog](https://www.changelog.langchain.com/). [LangChain](https://python.langchain.com/docs/introduction/)[LangSmith](https://docs.smith.langchain.com/)[LangGraph](https://langchain-ai.github.io/langgraph/tutorials/introduction/). [LangChain](https://js.langchain.com/docs/tutorials/)[LangSmith](https://docs.smith.langchain.com/)[LangGraph](https://langchain-ai.github.io/langgraphjs/tutorials/quickstart/). [About](https://www.langchain.com/about)[Careers](https://www.langchain.com/careers). [Pricing](https://www.langchain.com/pricing). [Get a demo](https://www.langchain.com/contact-sales). [Sign up](https://smith.langchain.com/). [Back to Announcements](https://changelog.langchain.com/). LangChain 1.0 now generally available. *   **create_agent abstraction**: The fastest way to build an agent with any model provider, built on LangGraph runtime for reliability. *   **Middleware system**: Fine-grained control at every step of the agent loop. Support for custom middleware lets you hook into any point in the agent execution. *   **Improved structured output generation**: Integrated directly into the main agent loop, reducing both latency and cost by eliminating extra LLM calls. Fine-grained control over generation strategy via tool calling or provider-native structured output. Legacy functionality has been moved to `langchain-classic` for backwards compatibility. Check out our new documentation at [docs.langchain.com](http://docs.langchain.com/) or read [our blog post to learn more.](https://blog.langchain.com/langchain-langgraph-1dot0/). **Release overviews:**[**Python**](https://docs.langchain.com/oss/python/releases/langchain-v1?ref=blog.langchain.com&ajs_aid=0774ee46-591d-412c-9f8a-5a5e3c7d21e3&ajs_uid=e4ce8b88-c947-4b00-a445-d0c3eb21f3be), [**JavaScript**](https://docs.langchain.com/ ...
#   AIMessage(content=[{'id': 'rs_0d9a4129d16179220069af7bc24ecc81909adfdabfd4ea96a7', 'summary': [], 'type': 'reasoning'}, {'arguments': '{"query":"DeepAgent LangChain DeepAgent release Deepagents LangChain deepagents documentation","max_results":10,"topic":"general","include_raw_content":false}', 'call_id': 'call_FKlFjHUXD3NGNHaQ9cKvmwjO', 'name': 'internet_search', 'type': 'function_call', 'id': 'fc_0d9a4129d16179220069af7bc306cc8190a0c97cf587b22836', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0d9a4129d16179220069af7bc1c3088190b7fb36185e8ceb14', 'created_at': 1773108161.0, 'metadata': {}, 'model': 'gpt-5-mini-2025-08-07', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07'}, id='resp_0d9a4129d16179220069af7bc1c3088190b7fb36185e8ceb14', tool_calls=[{'name': 'internet_search', 'args': {'query': 'DeepAgent LangChain DeepAgent release Deepagents LangChain deepagents documentation', 'max_results': 10, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_FKlFjHUXD3NGNHaQ9cKvmwjO', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 8071, 'output_tokens': 92, 'total_tokens': 8163, 'input_token_details': {'cache_read': 5376}, 'output_token_details': {'reasoning': 0}}),
#   ToolMessage(content='{"query": "DeepAgent LangChain DeepAgent release Deepagents LangChain deepagents documentation", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://github.com/langchain-ai/deepagents", "title": "GitHub - langchain-ai/deepagents: Deep Agents is an agent harness ...", "content": "Deep Agents is an agent harness built on langchain and langgraph. Instead of wiring up prompts, tools, and context management yourself, you get a working agent immediately and customize what you need. * **Sub-agents** — `task` for delegating work with isolated context windows. from deepagents import create_deep_agent agent = create_deep_agent result = agent invoke \\"messages\\" \\"role\\" \\"user\\" \\"content\\" \\"Research LangGraph and write a summary\\". Add your own tools, swap models, customize prompts, configure sub-agents, and more. from langchain chat_models import init_chat_model agent = create_deep_agent model = init_chat_model\\"openai:gpt-4o\\" tools = my_custom_tool system_prompt =\\"You are a research assistant.\\". * **Batteries included** — Planning, file access, sub-agents, and context management work out of the box. * **Get started in seconds** — `pip install deepagents` or `uv add deepagents` and you have a working agent. * reference.langchain.com/python – API reference docs for Deep Agents packages. | `deepagents` | Core SDK — `create_deep_agent`, middleware, backends |. Deep Agents is an agent harness built on langchain and langgraph.", "score": 0.9999722, "raw_content": null}, {"url": "https://docs.langchain.com/oss/python/deepagents/cli/overview", "title": "Deep Agents CLI - Docs by LangChain", "content": "`uv tool install deepagents-cli. uv tool install \'deepagents-cli[anthropic]\'. `deepagents --model anthropic:claude-opus-4-5`. `export DEEPAGENTS_LANGSMITH_PROJECT=\\"my-deep-agent-execution\\"`. deepagents --model anthropic:claude-sonnet-4-5. deepagents --sandbox modal # or runloop, daytona. | `deepagents list` | List all agents |. | `deepagents skills list [--project]` | List all skills (alias: `ls`) |. | `deepagents skills info NAME [--project]` | Show detailed information about a skill |. | `deepagents skills delete NAME [--project] [-f]` | Delete a skill and its contents |. | `deepagents threads list [--agent NAME] [--limit N]` | List sessions (alias: `ls`). `deepagents skills create NAME [--project]`. `deepagents skills info NAME [--project]`. `deepagents skills delete NAME [--project] [-f]`. `deepagents threads list [--agent NAME] [--limit N]`. deepagents -n \\"List dependencies\\" -q --no-stream | sort`. `deepagents -n \\"Run the tests and fix failures\\" --shell-allow-list \\"pytest,git,make\\". deepagents -n \\"Build the project\\" --shell-allow-list recommended`. `deepagents skills create test-skill`. `deepagents skills create test-skill --project`. `mkdir -p ~/.deepagents/<agent_name>/skills. cp -r examples/skills/web-research ~/.deepagents/<agent_name>/skills/`. `deepagents skills info test-skill --project`.", "score": 0.99993396, "raw_content": null}, {"url": "https://github.com/langchain-ai/deepagents/releases", "title": "Releases · langchain-ai/deepagents - GitHub", "content": "fix(sdk): add timeout to glob in FilesystemMiddleware (#1508). chore(sdk): add coverage to Makefile (#1493). fix(sdk): correct imports and mock inheritance in filesystem middleware tests (#1464). fix(sdk): warn on virtual mode (#1462). chore(sdk): add more eval test cases (#1452). test(sdk): add smoke test for system prompt with memory and skills (#1430). chore(sdk): adapt integration tests to evals framework (#1426). feat(sdk): add per-command `timeout` override to `execute()` (#1154). chore(sdk): add more evals (#1404). chore(sdk): minor updates to system message (#1367). chore(sdk): add model parameterization to evals (#1408). chore(sdk): add simple eval scaffolding (#1400). chore(sdk): add smoke tests for system message (#1363). feat(sdk): enable type checking in deepagents ...
#   AIMessage(content=[{'id': 'rs_0d9a4129d16179220069af7bc5d7648190847a6ae3a1c5d9b3', 'summary': [], 'type': 'reasoning'}, {'arguments': '{"query":"LangSmith description LangSmith features LangSmith LangChain evaluation LangSmith studio LangSmith deployment", "max_results":10,"topic":"general","include_raw_content":false}', 'call_id': 'call_oNdFMZqQpI9wLkqtDQETSMyH', 'name': 'internet_search', 'type': 'function_call', 'id': 'fc_0d9a4129d16179220069af7bc89b7c81908cde42b80a9be816', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0d9a4129d16179220069af7bc557d88190a495d871c7832ba4', 'created_at': 1773108165.0, 'metadata': {}, 'model': 'gpt-5-mini-2025-08-07', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07'}, id='resp_0d9a4129d16179220069af7bc557d88190a495d871c7832ba4', tool_calls=[{'name': 'internet_search', 'args': {'query': 'LangSmith description LangSmith features LangSmith LangChain evaluation LangSmith studio LangSmith deployment', 'max_results': 10, 'topic': 'general', 'include_raw_content': False}, 'id': 'call_oNdFMZqQpI9wLkqtDQETSMyH', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 11183, 'output_tokens': 245, 'total_tokens': 11428, 'input_token_details': {'cache_read': 8064}, 'output_token_details': {'reasoning': 192}}),
#   ToolMessage(content='{"query": "LangSmith description LangSmith features LangSmith LangChain evaluation LangSmith studio LangSmith deployment", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://changelog.langchain.com/announcements/product-naming-changes-langsmith-deployment-and-langsmith-studio", "title": "Product naming changes: LangSmith Deployment and LangSmith ...", "content": "# Product naming changes: LangSmith Deployment and LangSmith Studio. We’ve updated product names across the LangSmith UI, docs, and website to make it clearer how our tools fit together. #### What changed. * **LangGraph Platform** is now **LangSmith Deployment**. * **LangGraph Studio** is now **LangSmith Studio**. * **LangSmith** has 3 services: LangSmith Observability, LangSmith Evaluation, and LangSmith Deployment. * **LangSmith Deployment** (formerly LangGraph Platform) provides purpose-built infrastructure for deploying and managing long-running agent workloads. * **LangSmith Studio** (formerly LangGraph Studio) provides an interactive IDE for debugging and improving your agents. Users of LangSmith Deployment on all plan types will have access to LangSmith Studio. These updates make it easier to understand the relationship between LangSmith’s observability, evaluation, and deployment capabilities. * **LangSmith Deployment:** Purpose-built infrastructure for deploying and managing long-running agent workloads. * No updates are needed on your end — this is a naming change only. + Users **do not** need to use LangSmith Observability or Evaluation to use Deployment.", "score": 0.99995124, "raw_content": null}, {"url": "https://support.langchain.com/articles/8854797554-what-is-langsmith?threadId=415b6c0d-d7a6-4519-bfe1-87c952c8e7c9", "title": "What is LangSmith? - LangChain Support", "content": "# What is LangSmith? LangSmith Observability·2 min read·Jan 30, 2026··. LangSmith is an Agent Engineering Platform for building, testing, and monitoring AI applications. LangSmith works with **any framework or library**. Whether you\'re using LangChain, LangGraph, or building with other tools and custom implementations, LangSmith integrates seamlessly into your workflow. LangSmith Observability gives you complete visibility into what your agents are actually doing. Deploy your agents with confidence using LangSmith\'s deployment capabilities. You can sign up for LangSmith for free at smith.langchain.com. * **Webinar**: Get started with LangSmith Tracing. * **Blog**: LangSmith OTel support (OpenTelemetry). **Does LangSmith support OpenTelemetry (OTel)?**. Yes, LangSmith supports OTel integration. **Can I use LangSmith Observability without LangSmith Evaluation?**. Yes, LangSmith\'s capabilities can be used independently based on your needs. **Can I self-host LangSmith?**. **Will LangSmith add latency to my application?**. LangSmith is designed to minimize impact on your application\'s performance. No, LangSmith does not train on customer data. Sign in with your LangSmith credentials to chat with LangChain Support.", "score": 0.99994934, "raw_content": null}, {"url": "https://docs.langchain.com/langsmith/studio", "title": "LangSmith Studio - Docs by LangChain", "content": "* [Test locally](/langsmith/local-server). * [Cloud quickstart](/langsmith/deployment-quickstart). * [Interact with a deployment using RemoteGraph](/langsmith/use-remote-graph). * [Add semantic search to your agent deployment](/langsmith/semantic-search). * [Configure Agent Server for scale](/langsmith/agent-server-scale). * [Cloud](/langsmith/deploy-to-cloud). * [Standalone servers](/langsmith/deploy-standalone-server). * [Quickstart](/langsmith/quick-start-studio). * [Runs, assistants, threads](/langsmith/use-studio). * [Traces, datasets, prompts](/langsmith/observability-studio). * [Add custom authentication](/langsmith/custom-auth). * [Set up custom authentication](/langsmith/set-up-custom-auth). * [Connect an authentication provider](/langsmith/ad ...
#   AIMessage(content=[{'id': 'rs_0d9a4129d16179220069af7bcca6488190a7150954521d1c35', 'summary': [], 'type': 'reasoning'}, {'type': 'text', 'text': "요약 먼저: LangChain 1.0은 기존의 에이전트/체인 생태계를 “안정적·운영용”으로 재정비한 메이저 릴리스입니다. 핵심은 (1) 상위 수준의 간단한 엔트리포인트(create_agent) + (2) 안정적이고 내구성 있는 런타임(LangGraph) + (3) 운영·관찰·평가용 플랫폼(LangSmith)을 명확히 분리·통합한 것 — 그리고 그 위에 Deep Agents(별도 SDK/CLI)가 추가되어 복잡한 다단계/하위 에이전트 워크플로우를 더 쉽게 만들 수 있게 됐습니다.\n\n아래 항목별로 정리하겠습니다.\n\n1) LangChain(프레임워크) — 무엇이고 1.0 전후 차이\n- 무엇인가\n  - LLM 기반 애플리케이션(체인, 프롬프트, 에이전트, 메모리, 검색/리트리벌, 툴 연동 등)을 구성·조립하는 오픈소스 프레임워크.\n  - 다양한 모델 제공자, 툴, 콜백, 커넥터를 추상화해 빠르게 프로토타입·배포 가능하게 해줌.\n- 1.0 이전\n  - 여러 실험적 API와 빠른 진화로 기능은 풍부했지만, 런타임/상태 지속성·운영 기능·일관된 안정성 측면에서 분화된 부분이 있었음.\n  - 에이전트 구현 방식(예: React agent 등)과 다양한 실험적 유틸이 혼재.\n- 1.0에서 달라진 점(핵심)\n  - create_agent 추상화: 어떤 모델 제공자든 빠르게 에이전트를 만드는 표준/최고수준 API (내부적으로 LangGraph 런타임에 기반).\n  - 미들웨어 시스템 도입: 에이전트 루프의 각 단계에 훅을 달아 세밀한 제어/감시/확장 가능.\n  - 구조화된 출력(Structured output) 통합: 에이전트 루프 안에서 구조화된 응답을 직접 지원해 불필요한 추가 LLM 호출을 줄이고 지연·비용 절감.\n  - 레거시 기능은 langchain-classic으로 이동: 기존 코드와의 호환성 유지를 위해 이전 API 집합을 별도 패키지로 분리.\n  - 안정성 약속: 1.0에서 2.0까지는 의도적으로 파괴적 변경을 최소화하겠다는 정책·문서화(마이그레이션 가이드 제공).\n  - 문서·마이그레이션 가이드(Python/JS) 제공: 변경된 API·패턴으로 전환하는 가이드라인이 있음.\n\n2) LangGraph — 무엇이고 1.0의 의미\n- 무엇인가\n  - 에이전트 실행을 그래프(노드/엣지) 모델로 표현하는 런타임/프레임워크. 복잡한 워크플로우(결정적 작업 + 에이전트적 컴포넌트 혼합)에 적합.\n- LangGraph v1(1.0)에서의 핵심 변화\n  - Durable state(내구적 상태): 에이전트 실행 상태를 자동으로 지속(persist) — 중단·재개, 다일(多日) 프로세스, 장기 승인 플로우 가능.\n  - 내장된 영속성(persistence): 별도 DB 코드 없이 워크플로우 상태 저장/재개가 가능.\n  - Human-in-the-loop 패턴: 실행을 일시중지하고 인간의 검토·승인 단계를 공식 API로 지원.\n  - 그래프 기반 실행 모델: 복잡한 흐름에 대해 더 세밀한 제어와 관찰 가능성 제공.\n  - 일부 기존 기능(예: langgraph.prebuilt)은 deprecate 되고 langchain.agents로 기능 재배치.\n- 요약: LangGraph는 “운영용 에이전트 런타임”으로 안정화되어 장기·복잡 워크플로우에 적합.\n\n3) LangSmith — 무엇이고 역할(변경 사항 포함)\n- 무엇인가\n  - Agent engineering 플랫폼(관찰·평가·배포를 한데 모은 제품군). 프레임워크(또는 자체 구현)와 독립적으로 작동.\n  - 주요 구성:\n    - Observability: 트레이싱(런/스텝/툴 호출 등)으로 에이전트 내부 동작을 시각화·디버그.\n    - Evaluation: 오프라인(개발 시)·온라인(프로덕션 트래픽) 평가 파이프라인, LLM-as-judge, 휴먼 라벨링 등.\n    - Deployment(이전 명칭: LangGraph Platform): 에이전트(Agent Server) 배포·관리 인프라.\n    - Studio(이전 명칭: LangGraph Studio): 에이전트 IDE — 실행흐름·트레이스·데이터셋·평가를 UI에서 조작·디버깅.\n- 1.0 주변의 제품 네이밍/정리\n  - 제품 이름 정비: LangGraph Platform → LangSmith Deployment, LangGraph Studio → LangSmith Studio 등으로 명확화.\n  - LangSmith는 관찰·평가·배포를 통합해 운영용 워크플로우(모니터링·알림·평가-테스트 사이클)를 지원.\n- 요약: LangSmith는 “운영·검증·배포” 계층을 담당하며, LangChain/LangGraph로 만든 시스템을 관찰·평가·호스팅하는 플랫폼 역할.\n\n4) Deep Agents(새로 나온 것) — 무엇이고 언제/왜 쓰는가\n- 무엇인가\n  - deepagents(별도 패키지/SDK + CLI): LangChain + LangGraph 위에서 동작하는 '에이전트 하네스(harness)'.\n  - 기본 제공 기능: 자동 계획(planning), TODO/작업 분해(write_todos 같은 도구 포함), 파일 시스템(가상/백엔드) 기반의 컨텍스트 관리, 메모리 미들웨어, 하위 에이전트(sub-agent) 생성(내장 task 도구), CLI(대화형 사용) 등.\n  - 핵심 API 패턴: create_deep_agent(빠른 시작), 미들웨어 구성으로 파일/메모리/스킬(사용자 정의 능력) 추가, subagent(task) 호출로 격리된 컨텍스트에서 작업 위임.\n- 장점 / 사용 사례\n  - 복잡한 멀티스텝 작업(리서치, 프로그래밍, 워크플로우 자동화)을 에이전트가 자체적으로 분해·조율하게 하고 싶을 때.\n  - 하위 에이전트를 띄워 별도 컨텍스트에서 병렬·격리 작업 수행(예: 외부 툴 호출, 별도의 검색/처리).\n  - 장기 실행·감사(auditability)·재현성(상태 보존) 필요할 때.\n  - 로컬 CLI나 서비스 형태로 빠르게 실험하고 배포하기 좋음.\n- 배포·도구\n  - PyPI 패키지, GitHub 레포지토리, 문서(Reference docs), CLI 명령어(deepagents …).\n- 요약: Deep Agents는 “배터리 포함형” 에이전트 SDK로, 보통 처음부터 복잡한 에이전트 아키텍처를 직접 조립하지 않고 빠르게 실용적인 멀티스텝/하위에이전트 기반 시스템을 만들고자 할 때 유용.\n\n5) 마이그레이션·도입 시 실무적 고려사항(간단 체크리스트)\n- 기존 코드가 많다면:\n  - LangChain 1.0 마이그레이션 가이드(Python/JS)를 먼저 확인.\n  - 레거시 API가 langchain-classic으로 남아 있으므로 점진적 전환 가능.\n- 에이전트를 운영할 계획이라면:\n  - LangGraph v1의 durable state/휴먼-인-루프/영속성 기능을 활용해 워크플로우 재설계 검토.\n  - LangSmith(Observability + Evaluation)을 통해 트레이싱·온라인 평가를 구성(프로덕션 모니터링·알람).\n- Deep Agents 도입 고려:\n  - 복잡한 멀티스텝 자동화·하위 에이전트가 필요한지 확인. 단순 Q&A·단일 툴 호출에는 과할 수 있음.\n  - CLI/SDK로 빠르게 프로토타입이 가능하나, 프로덕션 배포는 LangSmith Deployment/Agent Server 연동을 검토.\n- 기타:\n  - 비용·지연: 구조화 출력 통합으로 일부 비용·지연 개선 가능. 그러나 상태·저장소를 늘리면 인프라·스토리지 비용이 발생할 수 있음.\n  - 보안·데이터 거버넌스: LangSmith 사용 시 데이터 처리·로그 정책(예: 민감데이터) 점검.\n\n6) 추가 리소스(문서/가이드)\n- LangChain 1.0 rel ...
