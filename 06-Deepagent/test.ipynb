# %% [markdown]
# # 06-deepagent/test.ipynb
#
# 1. csv 파일을 받아서
# 2. 데이터 분석을 진행하고
# 3. 슬랙으로 결과를 보냄
#
#
# ``` sh
# uv pip install deepagents slack-sdk langchain-daytona
# ```
# *-sdk: slack development kit*
#
# API키 생성 필요 - [daytona 사이트](https://app.daytona.io/)

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Daytona Sandbox

# %%
from daytona import Daytona
from langchain_daytona import DaytonaSandbox

sandbox = Daytona().create()
backend = DaytonaSandbox(sandbox=sandbox)

# %%
result = backend.execute('ls -a')
print(result.output)
# Out:
# .
# ..
# .bash_logout
# .bashrc
# .daytona
# .face
# .face.icon
# .profile
# .zshrc

# %%
import csv
import io

data = [
    ["Date", "Product", "Units Sold", "Revenue"],
    ["2025-08-01", "Widget A", 10, 250],
    ["2025-08-02", "Widget B", 5, 125],
    ["2025-08-03", "Widget A", 7, 175],
    ["2025-08-04", "Widget C", 3, 90],
    ["2025-08-05", "Widget B", 8, 200],
]

buf = io.StringIO()
writer = csv.writer(buf)
writer.writerows(data)

# 원본 csv 데이터
csv_bytes = buf.getvalue().encode('utf-8')
buf.close()

# 파일 저장(지금 우리는 필요 없음)
with open('./sales.csv', 'wb') as f:
    f.write(csv_bytes)

# sandbox 에 업로드
backend.upload_files(
    [
        ('/home/daytona/data/sales_data.csv', csv_bytes)
    ]
)
# Out:
# [FileUploadResponse(path='/home/daytona/data/sales_data.csv', error=None)]

# %% [markdown]
# ## Slack
# - Agent가 사용할 Slack Messaging Tool 생성

# %%
import os
from slack_sdk import WebClient

SLACK_BOT_TOKEN = os.getenv('SLACK_BOT_TOKEN')

client = WebClient(token=SLACK_BOT_TOKEN)

# 봇이 접근 가능한 모든 채널 리스트
res = client.conversations_list()
for ch in res['channels']:
    print(ch['name'], ch['id'])

social_channel_id = 'C0A3WG5C7R9'

client.chat_postMessage(
    channel=social_channel_id,
    text='hello'
)
# Out:
# 소셜 C0A3WG5C7R9
# slack-전체 C0A40SD1RAA
# 새-채널 C0A42THA7QA
# 오늘의-ai-트렌드 C0A6JS17MMM
# 오늘의-ai-트렌드-요약 C0A7D7K3A5P
# trend-tracker C0A7SRR0TRS
# trend-tracker-insight C0A8265KPLZ
# output-test C0ACS2AFYBG
# input-test C0ACXMAJJSG

# %%
import os
from slack_sdk import WebClient
from langchain.tools import tool

SLACK_TOKEN = os.getenv('SLACK_BOT_TOKEN')
slack_client = WebClient(token=SLACK_TOKEN)


@tool(parse_docstring=True)  # LLM에게 Tool 설명을 docstring 에서 제공
def send_slack_message(text: str, file_path: str | None = None) -> str:
    """메세지 전송, 경우에 따라 이미지같은 파일을 첨부함
    
    Args:
        text: (str) 메세지의 내용
        file_path: (str) 파일시스템 상 첨부파일의 경로
    """

    social_channel_id = 'C0A3WG6GLQK'
    # 첨부 파일 없으면
    if not file_path:
        slack_client.chat_postMessage(channel=social_channel_id, text=text)
    else:
        fp = backend.download_files([file_path])
        slack_client.files_upload_v2(
            channel=social_channel_id,
            content=fp[0].content,
            initial_comment=text,
        )
    
    return 'Message sent.'

# %% [markdown]
# ## Build Deep Agent

# %%
import uuid

from langgraph.checkpoint.memory import InMemorySaver
from deepagents import create_deep_agent

checkpointer = InMemorySaver()

agent = create_deep_agent(
    model='openai:gpt-5-mini',
    tools=[send_slack_message],
    backend=backend,
    checkpointer=checkpointer,
)

thread_id = str(uuid.uuid4())
config = {'configurable': {'thread_id': thread_id}}

# %%
input_message = {
    'role': 'user',
    'content': '''
    현재 폴더 안에 ./data/sales_data.csv 파일을 분석하고, 시각화 해줘.
    다 끝나면 분석결과와 시각화 이미지를 Slack 메세지로 보내줘.
    '''
}

for step in agent.stream(
    {"messages": [input_message]},
    config,
    stream_mode="updates",
):
    for _, update in step.items():
        if update and (messages := update.get("messages")) and isinstance(messages, list):
            for message in messages:
                message.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# [{'id': 'rs_00c4ee3d1deaa1cf0069afb1a6f4208197975d705509924a5c', 'summary': [], 'type': 'reasoning'}, {'arguments': '{"file_path":"/data/sales_data.csv","offset":0,"limit":2000}', 'call_id': 'call_OS3ebSU2q2SMTMce7L2zxyHU', 'name': 'read_file', 'type': 'function_call', 'id': 'fc_00c4ee3d1deaa1cf0069afb1a980688197a9917e8358ed0710', 'status': 'completed'}]
# Tool Calls:
#   read_file (call_OS3ebSU2q2SMTMce7L2zxyHU)
#  Call ID: call_OS3ebSU2q2SMTMce7L2zxyHU
#   Args:
#     file_path: /data/sales_data.csv
#     offset: 0
#     limit: 2000
# ================================= Tool Message =================================
# Name: read_file
#
# Error: File '/data/sales_data.csv' not found
# ================================== Ai Message ==================================
#
# [{'id': 'rs_00c4ee3d1deaa1cf0069afb1ab790081978d42efed35d8a8d9', 'summary': [], 'type': 'reasoning'}, {'arguments': '{"pattern":"**/sales_data.csv","path":"/"}', 'call_id': 'call_qXdV64BzJ9YLdtLckx6YxQRB', 'name': 'glob', 'type': 'function_call', 'id': 'fc_00c4ee3d1deaa1cf0069afb1aceba881979cd2644b46adbf5e', 'status': 'completed'}]
# Tool Calls:
#   glob (call_qXdV64BzJ9YLdtLckx6YxQRB)
#  Call ID: call_qXdV64BzJ9YLdtLckx6YxQRB
#   Args:
#     pattern: **/sales_data.csv
#     path: /

# %%
input_message = {
    'role': 'user',
    'content': '''
    채널은 기본 세팅 되어있음. 2번 데이터 시각화 해서 슬랙 메시지로 보내줘
    '''
}

for step in agent.stream(
    {"messages": [input_message]},
    config,
    stream_mode="updates",
):
    for _, update in step.items():
        if update and (messages := update.get("messages")) and isinstance(messages, list):
            for message in messages:
                message.pretty_print()
